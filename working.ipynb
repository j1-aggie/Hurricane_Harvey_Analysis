# %%
#Set dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gmaps
import os
from pprint import pprint
from scipy.stats import linregress
import scipy.stats as st
#from citypy import citipy


#import API key
from config import g_key

#import csv 
#Hurc_df= "..data/Harvey_2017.csv"

# %%
# Read the csv and the study results
csv_import = os.path.join("..", "data", "Harvey_2017.csv")
Hurc_df = pd.read_csv(csv_import)

# Combine the data into a single dataset
#combined_data = pd.merge(salinty_df, temp_results_df, on="Platform ID")

# Display the data table for preview
Hurc_df
# Out:
#        Unnamed: 0  Unnamed: 0.1                    sensor  \
# 0               0             0  ioos:station:wmo:42043:1
# 1               1             1  ioos:station:wmo:42043:1
# 2               2             2  ioos:station:wmo:42043:1
# 3               3             3  ioos:station:wmo:42043:1
# 4               4             4  ioos:station:wmo:42043:1
# ...           ...           ...                       ...
# 22013        1435          1435     ioos:station:TABS:X:1
# 22014        1436          1436     ioos:station:TABS:X:1
# 22015        1437          1437     ioos:station:TABS:X:1
# 22016        1438          1438     ioos:station:TABS:X:1
# 22017        1439          1439     ioos:station:TABS:X:1
#
#                             date  latitude  longitude  air_pressure(mBar)  \
# 0      2017-06-07 00:00:00+00:00   28.9818   -94.9186             1006.28
# 1      2017-06-07 00:30:00+00:00   28.9818   -94.9186             1006.65
# ...

# %%
Hurc_df.nunique()
# Out:
# Unnamed: 0                       1488
# Unnamed: 0.1                     1488
# sensor                              6
# date                             8404
# latitude                            6
# longitude                           6
# air_pressure(mBar)               1842
# air_temperature                   239
# sea_water_practical_salinity     2663
# sea_water_temperature             612
# wind_speed                      14259
# dtype: int64

# %%
SWater_Temp = Hurc_df("sea water temperature")
#Date = md.
plt.plot(xAxis, yAxis )
plt.title('Surface Water Temperature')
plt.xlabel('Date')
plt.ylabel('Surface Water Temp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0e56f9be4427> in <module>
# ----> 1 SWater_Temp = Hurc_df("sea water temperature")
#       2 #Date = md.
#       3 plt.plot(xAxis, yAxis )
#       4 plt.title('Surface Water Temperature')
#       5 plt.xlabel('Date')
#
# TypeError: 'DataFrame' object is not callable
